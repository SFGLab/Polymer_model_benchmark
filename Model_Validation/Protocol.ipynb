# %%
from validation_protocol import *
from loopsage.utils import get_coordinates_cif

# %%
V1 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/MultiEM_HiC/MultiEM_minimized.cif')
V2 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/LoopSage_ChIA-PET.cif')

heat1 = get_heat(V1)
heat2 = get_heat(V2)

# %%
compare_heats(heat1,heat2)
# Out:
# power is -0.1802 with error +/-0.0033
# Experimental power law fit: -0.18017383929904435 =/- 0.0032566770842353005
# power is -0.2383 with error +/-0.0032
# Simulated power law fit: -0.23829147859942634 =/- 0.003199932107382005
#
# ---- Correlations -----
# Correlations of random model. {'Pearson Correlation': 0.8187871934193985, 'Spearman Correlation': 0.6054950520527457, 'Kendall-Tau Correlation': 0.4304979586472471, 'Mean Squared Error': 0.36242561316120303}
#
# ---- Computer Vision Metrics -----
# FID Score (random): 6.125833371936806
#
# SSIM Score (random): 0.9374459603775092
#
# GMSD Score (random): 0.14958541756288563
#
# Phase Correlation Score (random): 0.5581021118561365
#
# ---Tests with Simulated Model---
# Mantel Test: Correlation=0.715, p-value=0.000
# KL Divergence: 0.233
# JS Divergence: 0.241
# Earth Mover’s Distance: 0.338
# Chi-Square Test: Statistic=1.459, p-value=1.000
# Bhattacharyya Coefficient: 23.105
# KS Test Statistic: 0.510, p-value=0.000
# ...

# %%
V1 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/LoopSage_HiC.cif')
V2 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/LoopSage_ChIA-PET.cif')

heat1 = get_heat(V1)
heat2 = get_heat(V2)

# %%
compare_heats(heat1,heat2)
# Out:
# power is -0.2423 with error +/-0.0024
# Experimental power law fit: -0.24227826756521725 =/- 0.0023552781316422263
# power is -0.2383 with error +/-0.0032
# Simulated power law fit: -0.23829147859942634 =/- 0.003199932107382005
#
# ---- Correlations -----
# Correlations of random model. {'Pearson Correlation': 0.661117180894079, 'Spearman Correlation': 0.7543814202499689, 'Kendall-Tau Correlation': 0.564335881948028, 'Mean Squared Error': 0.6777656382118428}
#
# ---- Computer Vision Metrics -----
# FID Score (random): 8.495723190585831
#
# SSIM Score (random): 0.9379646807217847
#
# GMSD Score (random): 0.15545812630748473
#
# Phase Correlation Score (random): 0.6358181628801274
#
# ---Tests with Simulated Model---
# Mantel Test: Correlation=0.724, p-value=0.000
# KL Divergence: 0.248
# JS Divergence: 0.225
# Earth Mover’s Distance: 0.458
# Chi-Square Test: Statistic=1.183, p-value=1.000
# Bhattacharyya Coefficient: 22.984
# KS Test Statistic: 0.328, p-value=0.000
# ...

# %%
V1 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/MultiEM_HiC/MultiEM_minimized.cif')
V2 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/MultiEM_ChIA-PET/MultiEM_minimized.cif')

heat1 = get_heat(V1)
heat2 = get_heat(V2)

# %%
compare_heats(heat1,heat2)
# Out:
# power is -0.1802 with error +/-0.0033
# Experimental power law fit: -0.18017383929904435 =/- 0.0032566770842353005
# power is -0.1977 with error +/-0.0030
# Simulated power law fit: -0.19766160590580972 =/- 0.0029892351759348342
#
# ---- Correlations -----
# Correlations of random model. {'Pearson Correlation': 0.6903402031267165, 'Spearman Correlation': 0.7216197943424311, 'Kendall-Tau Correlation': 0.53020207971752, 'Mean Squared Error': 0.619319593746567}
#
# ---- Computer Vision Metrics -----
# FID Score (random): 4.647083969698898
#
# SSIM Score (random): 0.9398606808625047
#
# GMSD Score (random): 0.164187633439041
#
# Phase Correlation Score (random): 0.6845476459910586
#
# ---Tests with Simulated Model---
# Mantel Test: Correlation=0.734, p-value=0.000
# KL Divergence: 0.041
# JS Divergence: 0.099
# Earth Mover’s Distance: 0.331
# Chi-Square Test: Statistic=0.091, p-value=1.000
# Bhattacharyya Coefficient: 28.417
# KS Test Statistic: 0.047, p-value=0.000
# ...

# %%
V1 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/LoopSage_ChIA-PET.cif')
V2 = get_coordinates_cif('/home/skorsak/Data/hackathon/results/MultiEM_ChIA-PET/MultiEM_minimized.cif')

heat1 = get_heat(V1)
heat2 = get_heat(V2)

# %%
compare_heats(heat1,heat2)
# Out:
# power is -0.2383 with error +/-0.0032
# Experimental power law fit: -0.23829147859942634 =/- 0.003199932107382005
# power is -0.1977 with error +/-0.0030
# Simulated power law fit: -0.19766160590580972 =/- 0.0029892351759348342
#
# ---- Correlations -----
# Correlations of random model. {'Pearson Correlation': 0.7178095354228259, 'Spearman Correlation': 0.7888332216046718, 'Kendall-Tau Correlation': 0.5933709729210926, 'Mean Squared Error': 0.5643809291543489}
#
# ---- Computer Vision Metrics -----
# FID Score (random): 8.036991210458723
#
# SSIM Score (random): 0.9250651961057619
#
# GMSD Score (random): 0.1679466584556054
#
# Phase Correlation Score (random): 0.6823071984841853
#
# ---Tests with Simulated Model---
# Mantel Test: Correlation=0.770, p-value=0.000
# KL Divergence: 0.066
# JS Divergence: 0.123
# Earth Mover’s Distance: 0.322
# Chi-Square Test: Statistic=0.178, p-value=1.000
# Bhattacharyya Coefficient: 27.412
# KS Test Statistic: 0.477, p-value=0.000
# ...
